# %%
腾讯识别发票

# %%
from tencentcloud.common import credential
from tencentcloud.common.profile.client_profile import ClientProfile
from tencentcloud.common.profile.http_profile import HttpProfile
from tencentcloud.common.exception.tencent_cloud_sdk_exception import TencentCloudSDKException 
from tencentcloud.ocr.v20181119 import ocr_client, models 
#image转base64
import base64
import os
import json

def img_ocr(path):
    with open(path,"rb") as f:#转为二进制格式
        base64_data = base64.b64encode(f.read())#使用base64进行加密
    
    try: 
        cred = credential.Credential("AKIDugfSXUrk6EAHBdD0tb5ZHlZBbopddzXk", "Xs14vjutBG9pBPQdcPyKT6btLacQ1PKA") 
        httpProfile = HttpProfile()
        httpProfile.endpoint = "ocr.tencentcloudapi.com"
    
        clientProfile = ClientProfile()
        clientProfile.httpProfile = httpProfile
        client = ocr_client.OcrClient(cred, "ap-shanghai", clientProfile) 
    
        req = models.VatInvoiceOCRRequest()
        #params = '{\"ImageBase64\":\"data:image/png;base64,...\"}'
        params = '{\"ImageBase64\":\"data:image/png;base64,%s"}'% base64_data.decode('ascii')
        
        req.from_json_string(params)
    
        resp = client.VatInvoiceOCR(req) 
        #print(resp.to_json_string()) 
        json_dict=json.loads(resp.to_json_string())
        #print(json)
        print(json_dict["VatInvoiceInfos"][5],json_dict["VatInvoiceInfos"][6],json_dict["VatInvoiceInfos"][11],json_dict["VatInvoiceInfos"][23],json_dict["VatInvoiceInfos"][26])
    except TencentCloudSDKException as err: 
        print(err)
path=r"D:\招标\发票\54 001"
for a,b,file in os.walk(path):
    
	print(11,file)
for i in file:
    f=os.path.join(path,i)
    print(f)
    img_ocr(f)
# Out:
# 11 ['000001.tif', '000002(1).jpg', '000003(1).jpg', '000004(1).jpg', '000005(1).jpg', '000006(1).jpg']
# D:\招标\发票\54 001\000001.tif
# {'Name': '合计税额', 'Value': '¥49.12'} {'Name': '合计金额', 'Value': '¥4911.50'} {'Name': '小写金额', 'Value': '¥4960.62'} {'Name': '销售方名称', 'Value': '上海吾加吾生物科技有限公司'} {'Name': '销售方识别号', 'Value': '91310117777629094L'}
# D:\招标\发票\54 001\000002(1).jpg
# {'Name': '合计税额', 'Value': '49.12'} {'Name': '合计金额', 'Value': '¥4911.50'} {'Name': '小写金额', 'Value': '¥4960.62'} {'Name': '销售方名称', 'Value': '上海普加吾生物科技有限公司'} {'Name': '销售方识别号', 'Value': '91310117777629094L'}
# D:\招标\发票\54 001\000003(1).jpg
# {'Name': '合计税额', 'Value': '¥931.86'} {'Name': '合计金额', 'Value': '¥7168.14'} {'Name': '小写金额', 'Value': '¥8100.00'} {'Name': '销售方名称', 'Value': '上海跃瑞实业有限公司'} {'Name': '销售方识别号', 'Value': '91310116MN1J90LY7T'}
# D:\招标\发票\54 001\000004(1).jpg
# ...

# %%
# encoding:utf-8
import requests 

# client_id 为官网获取的AK， client_secret 为官网获取的SK
host = 'https://aip.baidubce.com/oauth/2.0/token?grant_type=client_credentials&client_id=swqZVSEowKyahlBoOO78y6XG&client_secret=h8ly8E0BsCe5zlmZjAIPsAkskIXSWyg3'
response = requests.get(host)
if response:
    print(response.json())
# Out:
# {'refresh_token': '25.2efcef65c06b5913ff299cdce4dc29cf.315360000.1914196218.282335-22323978', 'expires_in': 2592000, 'session_key': '9mzdCytE+QMPCrgq1NSM0Jp7goK4kLGoQVO5QhFKoI0GdBkY72Li1mpwxiqHivMr0q/A44DWko62Q7dCh5XWIjdSixUHog==', 'access_token': '24.0399d63caef2f5d21ea6f5df0c251edb.2592000.1601428218.282335-22323978', 'scope': 'public vis-ocr_ocr brain_ocr_scope brain_ocr_general brain_ocr_general_basic vis-ocr_business_license brain_ocr_webimage brain_all_scope brain_ocr_idcard brain_ocr_driving_license brain_ocr_vehicle_license vis-ocr_plate_number brain_solution brain_ocr_plate_number brain_ocr_accurate brain_ocr_accurate_basic brain_ocr_receipt brain_ocr_business_license brain_solution_iocr brain_qrcode brain_ocr_handwriting brain_ocr_passport brain_ocr_vat_invoice brain_numbers brain_ocr_business_card brain_ocr_train_ticket brain_ocr_taxi_receipt vis-ocr_household_register vis-ocr_vis-classify_birth_certificate vis-ocr_台湾通行证 vis-ocr_港澳通行证 vis-ocr_机动车购车发票识别 vis-ocr_机动车检验合格证识别 v
# ...

# %%
# encoding:utf-8

import requests
import base64

'''
表格文字识别(同步接口)
'''

request_url = "https://aip.baidubce.com/rest/2.0/ocr/v1/form"
# 二进制方式打开图片文件
f = open(r"C:\Users\lenovo\Desktop\wenzishibie.png", 'rb')
img = base64.b64encode(f.read())

params = {"image":img}
access_token =  '24.90054ffb52b58350cd1e1552f45706c0.2592000.1601178684.282335-22323978'
request_url = request_url + "?access_token=" + access_token
headers = {'content-type': 'application/x-www-form-urlencoded'}
response = requests.post(request_url, data=params, headers=headers)
if response:
    print (response.json())
# Out:
# {'error_code': 6, 'error_msg': 'No permission to access data'}

# %%
# encoding:utf-8

import requests
import base64

request_url = "https://aip.baidubce.com/rest/2.0/ocr/v1/general"
# 二进制方式打开图片文件
f = open(r"C:\Users\lenovo\Desktop\wenzishibie.png", 'rb')
img = base64.b64encode(f.read())

params = {"image":img}
access_token = '24.90054ffb52b58350cd1e1552f45706c0.2592000.1601178684.282335-22323978'
request_url = request_url + "?access_token=" + access_token
headers = {'content-type': 'application/x-www-form-urlencoded'}
response = requests.post(request_url, data=params, headers=headers)
if response:
    print (response.json())
# Out:
# {'words_result': [{'words': '通用文字识别(高精度版)', 'location': {'top': 2, 'left': 2, 'width': 169, 'height': 17}}], 'log_id': 1299232039001653248, 'words_result_num': 1}

# %%
# encoding:utf-8

import requests
import base64

'''
表格文字识别(异步接口)
'''

request_url = "https://aip.baidubce.com/rest/2.0/solution/v1/form_ocr/request"
# 二进制方式打开图片文件
f = open(r"C:\Users\lenovo\Desktop\wenzishibie2.png", 'rb')
img = base64.b64encode(f.read())

params = {"image":img}
access_token ='24.90054ffb52b58350cd1e1552f45706c0.2592000.1601178684.282335-22323978'
request_url = request_url + "?access_token=" + access_token
headers = {'content-type': 'application/x-www-form-urlencoded'}
response = requests.post(request_url, data=params, headers=headers)
if response:
    print (response.json())
# Out:
# {'result': [{'request_id': '22323978_2081832'}], 'log_id': 1598603006567794}

# %%
# encoding:utf-8

import requests
import base64

'''
表格文字识别(异步接口)
'''

request_url = "https://aip.baidubce.com/rest/2.0/solution/v1/form_ocr/get_request_result"
# 二进制方式打开图片文件
f = open(r"C:\Users\lenovo\Desktop\wenzishibie2.png", 'rb')
img = base64.b64encode(f.read())

params = {"request_id":'22323978_2081832','result_type':'json'}
access_token ='24.90054ffb52b58350cd1e1552f45706c0.2592000.1601178684.282335-22323978'
request_url = request_url + "?access_token=" + access_token
headers = {'content-type': 'application/x-www-form-urlencoded'}
response = requests.post(request_url, data=params, headers=headers)
if response:
    print (response.json())
# Out:
# {'result': {'result_data': '{"form_num":1,"forms":[{"footer":[{"rect":{"top":75,"left":312,"width":97,"height":18},"column":[1],"row":[1],"word":"发货人:葛成霞"},{"rect":{"top":429,"left":311,"width":101,"height":16},"column":[1],"row":[2],"word":"收货人(签字):"},{"rect":{"top":613,"left":308,"width":191,"height":24},"column":[1],"row":[3],"word":"发货单(盖章)56499"},{"rect":{"top":675,"left":319,"width":51,"height":26},"column":[1],"row":[4],"word":"9"},{"rect":{"top":692,"left":332,"width":87,"height":44},"column":[1],"row":[5],"word":"发票专用章"}],"header":[{"rect":{"top":324,"left":31,"width":318,"height":28},"column":[1],"row":[1],"word":"上海领聪医疗器械商行送货单"},{"rect":{"top":396,"left":84,"width":169,"height":23},"column":[1],"row":[2],"word":"2020年8月26日"},{"rect":{"top":117,"left":116,"width":286,"height":18},"column":[1],"row":[3],"word":"收货单位:台州和合后勤管理服务有限公司"},{"rect":{"top":531,"left":112,"width":298,"height":17},"column":[1],"row":[4],"word":"经营许可证号:沪金食药监械经营许20150251号"}],"body":[{"rect":{"top":154,"l
# ...

# %% [markdown]
# 医院系统

# %%
# encoding:utf-8

import requests
import json


request_url = "http://218.75.11.68:8001/CHD-SUP/hrp/sup/supdeliverymain/addDeliveryGenerateDetail.do?isCheck=false"


params = {"sup_id":5661257,
          'sup_no':1257,
          'is_dir':0,
          'bill_type':1,
          'delivery_address':'浙江省台州市经济开发区育德路369号二楼（台州市中心医院住院部B幢南面米谷美食楼上）台州市中心医院采购中心仓库(2)，周官官收,13867683440',
          'detailData':[{"copy_code":"01","bid_code":"阳光150812160","not_ship_amount":20,"is_com":0,"cert_id":53587,"inv_name":"二件式造口袋(商品名：胜舒)-肠造口袋","is_bar":0,"price":"29.10000","order_amount":100,"is_quality":1,"inv_model":"10386","unit_code":"3","store_name":"卫生材料库房","inv_id":13319,"store_id":4,"amount":1,"hos_id":3,"amount_money":"29.1000","order_code":"DD20200800918","unit_name":"只","fac_name":"丹麦Coloplast A/S","order_detail_id":69693,"order_date":"2020-08-26","group_id":1,"inv_code":"0214000014","order_id":34884,"inv_no":133551,"notEidtColNames":[],"__id":"r1001","__previd":-1,"__index":0,"__status":"update","batch_no":"pihao","fac_date":"2000-01-01 00:00:00","inva_date":"2002-02-02 00:00:00","disinfect_date":"2003-03-03 00:00:00","disinfect_no":"20040404"}]
         }


headers = {
    'content-type': 'application/json;charset=UTF-8',
    'Cookie':'JSESSIONID=C868DAF17F12C10B7B9EFB5920B0F386; liger-home-tab=%5B%7B%22tabid%22%3A1598837687255%2C%22text%22%3A%22%E9%80%81%E8%B4%A7%E5%8D%95%E7%BC%96%E5%88%B6%22%2C%22url%22%3A%22hrp%2Fsup%2Fsupdeliverymain%2FsupDeliveryMainMainPage.do%3FisCheck%3Dfalse%22%7D%5D',
    'Accept':'application/json, text/javascript, */*; q=0.01',
    'Accept-Encoding':'gzip, deflate',
    'Accept-Language':'zh-CN,zh;q=0.9',
    'Connection':'keep-alive',
    'Content-Length':'1971',
    'Host':'218.75.11.68:8001',
    'Origin':'http://218.75.11.68:8001',
    'Referer':'http://218.75.11.68:8001/CHD-SUP/hrp/sup/supdeliverymain/orderImpDetailPage.do?isCheck=false&sup_id=566,1257&sup_text=TZ0206%20%E5%8F%B0%E5%B7%9E%E5%92%8C%E5%90%88%E5%90%8E%E5%8B%A4%E7%AE%A1%E7%90%86%E6%9C%8D%E5%8A%A1%E6%9C%89%E9%99%90%E5%85%AC%E5%8F%B8',
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.135 Safari/537.36',
    'X-Requested-With':'XMLHttpRequest'
}
response = requests.post(request_url, data=params, headers=headers)
if response:
    print (response.json)
    print(response.status_code)
# Out:
# <bound method Response.json of <Response [200]>>
# 200

# %% [markdown]
# 测试post接口

# %%
# encoding:utf-8

import requests
import json


request_url = "http://218.75.11.68:8001/CHD-SUP/hrp/sup/queryDeptDictLast.do?isCheck=false"


params = {
        #"sup_id":'566,1257',
         # 'sup_no':'1257',
          #'is_dir':'0',
          #'bill_type':'1',
          'delivery_address':'浙江省台州市经济开发区育德路369号二楼（台州市中心医院住院部B幢南面米谷美食楼上）台州市中心医院采购中心仓库(2)，周官官收,13867683440',
          'detailData':[{"copy_code":"01","bid_code":"阳光150812160","not_ship_amount":20,"is_com":0,"cert_id":53587,"inv_name":"二件式造口袋(商品名：胜舒)-肠造口袋","is_bar":0,"price":"29.10000","order_amount":100,"is_quality":1,"inv_model":"10386","unit_code":"3","store_name":"卫生材料库房","inv_id":13319,"store_id":4,"amount":1,"hos_id":3,"amount_money":"29.1000","order_code":"DD20200800918","unit_name":"只","fac_name":"丹麦Coloplast A/S","order_detail_id":69693,"order_date":"2020-08-26","group_id":1,"inv_code":"0214000014","order_id":34884,"inv_no":133551,"notEidtColNames":[],"__id":"r1001","__previd":-1,"__index":0,"__status":"update","batch_no":"pihao","fac_date":"2000-01-01 00:00:00","inva_date":"2002-02-02 00:00:00","disinfect_date":"2003-03-03 00:00:00","disinfect_no":"20040404"}]
         }


headers = {
    'content-type': 'application/json;charset=UTF-8',
    'Cookie':'JSESSIONID=C868DAF17F12C10B7B9EFB5920B0F386; liger-home-tab=%5B%7B%22tabid%22%3A1598837687255%2C%22text%22%3A%22%E9%80%81%E8%B4%A7%E5%8D%95%E7%BC%96%E5%88%B6%22%2C%22url%22%3A%22hrp%2Fsup%2Fsupdeliverymain%2FsupDeliveryMainMainPage.do%3FisCheck%3Dfalse%22%7D%5D',
    'Accept':'application/json, text/javascript, */*; q=0.01',
    'Accept-Encoding':'gzip, deflate',
    'Accept-Language':'zh-CN,zh;q=0.9',
    'Connection':'keep-alive',
    'Content-Length':'1971',
    'Host':'218.75.11.68:8001',
    'Origin':'http://218.75.11.68:8001',
    'Referer':'http://218.75.11.68:8001/CHD-SUP/hrp/sup/supdeliverymain/orderImpDetailPage.do?isCheck=false&sup_id=566,1257&sup_text=TZ0206%20%E5%8F%B0%E5%B7%9E%E5%92%8C%E5%90%88%E5%90%8E%E5%8B%A4%E7%AE%A1%E7%90%86%E6%9C%8D%E5%8A%A1%E6%9C%89%E9%99%90%E5%85%AC%E5%8F%B8',
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.135 Safari/537.36',
    'X-Requested-With':'XMLHttpRequest'
}
response = requests.post(request_url, data=params, headers=headers)
if response:
    print (response.text)
# Out:
# [{"id":"3.3","text":"130106 妇产科病房"},{"id":"4.4","text":"300120 B四西病区护理"},{"id":"6.6","text":"191101 A九西-日间病房"},{"id":"7.7","text":"300126 B七西病区护理"},{"id":"8.8","text":"300127 A七西病区护理"},{"id":"9.9","text":"190203 针灸科"},{"id":"10.10","text":"300197 重症监护护理"},{"id":"11.11","text":"300130 B八东病区护理"},{"id":"12.12","text":"300131 B八西病区护理"},{"id":"14.14","text":"400601 质量改进处"},{"id":"15.15","text":"190102 A四西-放疗科病房"},{"id":"16.16","text":"110603 A六东-神经内科二病房"},{"id":"18.18","text":"300806 物业组"},{"id":"25.25","text":"20050201 心内科DSA"},{"id":"26.26","text":"20050202 神经内科DSA"},{"id":"27.27","text":"20050203 神经外科DSA"},{"id":"28.28","text":"20050204 DSA中心"},{"id":"29.29","text":"4098 临床教学办公室"},{"id":"32.32","text":"409902 院外单位"},{"id":"33.38","text":"199902 外一科门诊"}]
